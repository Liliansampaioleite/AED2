# %%
Idade = int(input("Digite a idade"))
Valor_total = float(input("Digite o valor total da Carteita"))
if Idade >= 16:
    print("verifique o dinheiro")
elif Valor_total >= 30.00:
        print("Ingresso comprado ! Bom filme ")
else:
    print("Saldo Insuficiente para o ingresso")
# Out:
# Digite a idade 14
# Digite o valor total da Carteita 35
# Ingresso comprado ! Bom filme

# %%
# Idade = int(input("Digite a idade"))
Valor_total = float(input("Digite o valor total da Carteita:"))
if Idade >= 16:
    print("Entrada permitida")    
elif Valor_total >= 30.00:
        print("Ingresso comprado ! Bom filme ")
else:
    print("Saldo Insuficiente para o ingresso")
for i in range (1):
    resposta = 0 
    proximo = input("Deseja verifcar outro usuario? (s/n):")
    if resposta == "n":
        print("Obrigado")
    else: 
        continue
# Out:
# Digite o valor total da Carteita: 21
# Entrada permitida
# Deseja verifcar outro usuario? (s/n): n
