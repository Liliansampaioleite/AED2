# %%
numero = int(input("Digite um numero"))
if numero % 3 == 0 and numero % 5 == 0:
    print("Ele é dividido pelos dois")
else:
    print("Ele não é divido por eles")
# Out:
# Digite um numero 15
# Ele é dividido pelos dois
