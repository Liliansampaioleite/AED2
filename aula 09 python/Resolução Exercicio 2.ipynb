# %%
valor_compra = float(input("Digite o valor_compra"))
if valor_compra <= 1.000:
    print(f"O valor_desconto é : {valor_compra * 0.10}")
elif valor_compra >= 5.000:
    print(f"O valor_desconto é : {valor_compra * 0.20}")
else:
    print(f"valor_desconto é : {valor_compra * 0.30}")
# Out:
# Digite o valor_compra 1500
# O valor_desconto é : 300.0
