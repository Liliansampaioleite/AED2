# %% [markdown]
# # Lista de exercícios AED1 - Parte 1

# %% [markdown]
# ### Exercício 0 - Faça um algoritmo para ler um número e mostrar se ele é par ou impar, positivo ou negativo.

# %%
numero = int(input("Digite um numero"))
if numero < 0:
    print("é negativo")
else:
    print("é positivo")
if numero % 2 == 0:
        print(f"{numero}Ele é par")
else:
        print(f"{numero}ele é impar")
# Out:
# Digite um numero -9
# é negativo
# ele é impar

# %% [markdown]
# ### Exercício 1 - Faça um Programa que peça dois números e imprima o maior deles.

# %%
numero1 = float(input("digite o primeiro numero"))
numero2 = float(input("digite o segundo numero"))
if numero1 > numero2:
    print(numero1)
elif numero2 > numero1:
        print(numero2)
else:
    print("os numeros são iguais")
# Out:
# digite o primeiro numero 10
# digite o segundo numero 5
# 10.0

# %% [markdown]
# ### Exercício 2 - Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

# %%
valor = float(input("Digite o valor"))
if valor > 0:
    print("positivo")
else:
    print("negativo")
# Out:
# Digite o valor 35
# positivo

# %% [markdown]
# ### Exercício 3 - Faça um Programa que verifique se uma letra digitada é vogal ou consoante.

# %%
letra = input("Digite a letra")
vogais = ("a","e","i","o","u")
if letra in vogais:
    print("{letra} é uma vogal")
else:
    print("Letra é uma consoante")
# Out:
# Digite a letra a
# a é uma vogal

# %% [markdown]
# ### Exercício 4 - Faça um programa para a leitura de duas notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
# ##### a. A mensagem "Aprovado", se a média alcançada for maior ou igual a sete;
# ##### b. A mensagem "Reprovado", se a média for menor do que sete;
# ##### c. A mensagem "Aprovado com Distinção", se a média for igual a dez.

# %%
nota1 = float(input("Digite a primeira nota"))
nota2 = float(input("Digite a segunda nota"))
média = (nota1 + nota2)/2
print(f"média é {média}")

if média == 10:
    print("Aprovado com Distinção")
elif média >=7:
    print("aprovado")
else:
    print("Reprovado")
# Out:
# Digite a primeira nota 10
# Digite a segunda nota 10
# média é 10.0
# Aprovado com Distinção

# %% [markdown]
# ### Exercício 5 - Faça um programa que pergunte o preço de três produtos e informe qual produto você deve comprar, sabendo que a decisão é sempre pelo mais barato.

# %%
valor1 = float(input("Digite o primeiro valor"))
valor2 = float(input("Digite o segundo valor"))
valor3 = float(input ("Digite o terceiro valor"))

if valor1 <= valor2 and valor1 <= valor3:
    print(f"valor 1 Compre {valor1} é o mais barato")
elif valor2 <= valor1 and valor2 <= valor3:
    print(f"compre o terceiro  é o mais barato")
else:
    print("compre! o Terceiro é o mais barato")
# Out:
# Digite o primeiro valor 24
# Digite o segundo valor 35
# Digite o terceiro valor 22
# compre! o Terceiro é o mais barato

# %% [markdown]
# ### Exercício 6 - Faça um Programa que leia três números e mostre-os em ordem decrescente.

# %%
n1= float(input("Insira um número:")) 
n2 = float(input("Insira um número:")) 
n3 = float(input("Insira um número:")) 
if n1 >= n2 and n1 >= n3: 
    if n2 >= n3:
        print(n1, n2, n3)
    else: 
        print(n1, n3, n2) 
elif n2 >= n1 and n2 >= n3: 
        if n1 >= n3:
            print(n2, n1, n3)
        else: 
                print(n2, n3, n1)
else: 
    if n1 >= n2: 
        print(n3, n1, n2)
    else:
        print(n3, n2, n1)
# Out:
# Insira um número: 47
# Insira um número: 28
# Insira um número: 67
# 67.0 47.0 28.0

# %% [markdown]
# n1 = float(input("Insira um número:"))
# n2 = float(input("Insira um número:"))
# n3 = float(input("Insira um número:"))
# if n1 >= n2 and n1 >= n3:
#     if n2 >= n3:
#         print(n1, n2, n3)
#     else:
#         print(n1, n3, n2)
# elif n2 >= n1 and n2 >= n3:
#     if n1 >= n3:
#         print(n2, n1, n3)
#     else:
#         print(n2, n3, n1)
# else:
#     if n1 >= n2:
#         print(n3, n1, n2)
#     else:
#         print(n3, n2, n1)

# %% [markdown]
# ### Exercício 7 - Faça um Programa que pergunte em que turno você estuda. Peça para digitar M-matutino ou V-Vespertino ou N- Noturno.
# Imprima a mensagem "Bom Dia!", "Boa Tarde!" ou "Boa Noite!" ou "Valor Inválido!", conforme o caso.

# %%
turno = input("Digite a letra do seu turno")
letras = "M","V","N"
if turno == "M":
    print("Bom dia ")
elif turno == "V":
    print("Boa tarde ")
elif turno == "N":
    print("Boa noite")
else:
    print("invalido!Digite M,N ou V")
# Out:
# Digite a letra do seu turno V
# Boa tarde

# %% [markdown]
# ### Exercício 8 - As Organizações Tabajara resolveram dar um aumento de salário aos seus colaboradores e lhe contraram para desenvolver o programa que calculará os reajustes.
# #### a. Faça um programa que recebe o salário de um colaborador e o reajuste segundo o seguinte critério, baseado no  salário atual:
#
# #### b. salários até R$ 280,00 (incluindo) : aumento de 20%
#
# #### c. salários entre R$ 280,00 e R$ 700,00 : aumento de 15%
#
# #### d. salários entre R$ 700,00 e R$ 1500,00 : aumento de 10%
#
# #### e. salários de R$ 1500,00 em diante : aumento de 5% Após o aumento ser realizado, informe na tela:
#
# #### f. o salário antes do reajuste;
#
# #### g. o percentual de aumento aplicado;
#
# #### h. o valor do aumento;
#
# #### i. o novo salário, após o aumento.

# %% [markdown]
# ## salario_base = float(input("Digite o valor do salario"))
# if salario_base <= 280.00:
#     percentual = 20
#
# elif salario_base <= 700.00:
#     percentual = 15
#
# elif salario_base <= 1500.00:
#     percentual = 10
# else:
#     percentual = 5
# aumento = salario_base * percentual/100
# novo_salario = salario_base + aumento
# print(f"sálario antes do reajuste {salario_base}")
# print(f"percentual {percentual}")
# print(f"Aumento foi de {aumento}")
# print(f"Novo Salario é : {novo_salario}")

# %%
salario_base  = float(input("Digite o Salario"))
if salario_base <= 2.800:
    pecentual = 20
elif salario_base <= 700:
    percentual = 15
elif salario_base <=1500:
    percentual = 10
else:
    percentual = 5

   
Aumento = salario_base * percentual / 100
Novo_salario = salario_base + Aumento
print("Salario antes do reajuste {salario_base}")
print("Percentual do aumento aplicado {percentual %}")
print("O valor do Aumento é: ",Aumento)
print("Novo salario:" ,Novo_salario)
# Out:
# Digite o Salario 2800
# Salario antes do reajuste {salario_base}
# Percentual do aumento aplicado {percentual %}
# O valor do Aumento é:  140.0
# Novo salario: 2940.0

# %% [markdown]
# ### Exercício 9 - Faça um programa para o cálculo de uma folha de pagamento, sabendo que os descontos são do Imposto de Renda, que depende do salário bruto (conforme tabela abaixo) e 3% para o Sindicato e que o FGTS corresponde a 11% do Salário Bruto, mas não é descontado (é a empresa que deposita). O Salário Líquido corresponde ao Salário Bruto menos os descontos. O programa deverá pedir ao usuário o valor da sua hora e a quantidade de horas trabalhadas no mês.

# %% [markdown]
# ##### a. Desconto do IR:
#
# ##### b. Salário Bruto até 900 (inclusive) - isento
#
# ##### c. Salário Bruto até 1500 (inclusive) - desconto de 5%
#
# ##### d. Salário Bruto até 2500 (inclusive) - desconto de 10%
#
# ##### e. Salário Bruto acima de 2500 - desconto de 20% Imprima na tela as informações, dispostas conforme o exemplo
#
# ##### abaixo. No exemplo o valor da hora é 5 e a quantidade de hora é 220

# %%
valor_hora = float(input("Qual o valor da hora trabalhada: "))
horas_trabalhadas = float(input("Digite a quantidade e horas_trabalhadas"))
salario_bruto = valor_hora * horas_trabalhadas
# 3. Definição do percentual do IR usando a tabela
if salario_bruto <= 900.00:
    percentual_ir = 0
elif salario_bruto <= 1500.00:
    percental_ir = 0.5   
elif salario_bruto <= 2500.00:
    percentual_ir = 0.10
   
else:
     percentual_ir = 0.20
    
valor_sindicato = salario_bruto * 0.03
valor_ir = salario_bruto * (percentual_ir)
total_desconto = valor_sindicato + valor_ir
salario_liquido = salario_bruto - valor_ir - valor_sindicato


print(f"salario Bruto: ({valor_hora} * {horas_trabalhadas}) : R$ {valor_hora * horas_trabalhadas:.2f}")
print(f"Desconto IR %): R$ {salario_bruto * (percentual_ir):.2f}")
print(f"Desconto Sindicato (3%): R$ {salario_bruto * 0.03:.2f}")
print(f"FGTS (11%): R$ {salario_bruto * 0.11:.2f}")
print(f"Total de descontos: R$ {valor_ir + valor_sindicato:.2f}")
print(f"Salário Liquido: R$ {salario_bruto - (valor_ir + valor_sindicato):.2f}")
# Out:
# Qual o valor da hora trabalhada:  36
# Digite a quantidade e horas_trabalhadas 192
# salario Bruto: (36.0 * 192.0) : R$ 6912.00
# Desconto IR %): R$ 1382.40
# Desconto Sindicato (3%): R$ 207.36
# FGTS (11%): R$ 760.32
# Total de descontos: R$ 1589.76
# Salário Liquido: R$ 5322.24

# %% [markdown]
# ### 10 - Faça um programa que lê as duas notas parciais obtidas por um aluno numa disciplina ao longo de um semestre, e calcule
# a sua média. A atribuição de conceitos obedece à tabela abaixo:

# %% [markdown]
# ##### a.   Média de Aproveitamento  Conceito
#
# ##### b.   Entre 9.0 e 10.0        A
#
# ##### c.   Entre 7.5 e 9.0         B
#
# ##### d.   Entre 6.0 e 7.5         C
#
# ##### e.   Entre 4.0 e 6.0         D
#
# ##### f.   Entre 4.0 e zero        E

# %%
nota1 = int(input("Digite a primeira nota "))
nota2 = int(input("Digite a segunda nota"))
media = float(nota1 + nota2) / 2
if media >= 9.0:
    print("média A")
elif media >= 7.5:
    print("média B")
elif media >= 6.0:
    print("média C")
elif media >= 4.0:
    print("média D")
else:
    print("media E")
# Out:
# Digite a primeira nota  2
# Digite a segunda nota 8
# média D
