# %%
import random
numero_secreto = random.randint(1, 50) 
tentativa = 0
print("Tente adivinhar o numero de 1 a 50")
while tentativa != numero_secreto:
    tentativa = int(input("Qual é o seu palpite"))
    if tentativa < numero_secreto :
        print("mais alto...")
    elif tentativa > numero_secreto:
        print("mais baixo...")
    else:
        print(f"Parabéns!!! você acertou! o numero é {numero_secreto}")
# Out:
# Tente adivinhar o numero de 1 a 50
# Qual é o seu palpite 5
# mais alto...
# Qual é o seu palpite 15
# mais alto...
# Qual é o seu palpite 25
# mais alto...
# Qual é o seu palpite 45
# mais baixo...
# Qual é o seu palpite 40
# mais baixo...
# Qual é o seu palpite 35
# mais baixo...
# Qual é o seu palpite 30
# mais alto...
# Qual é o seu palpite 32
# Parabéns!!! você acertou! o numero é 32

# %%
import random
n_secreto = random.randint(1, 50)

for i in range(5):
    palpite = int(input("Digite um numero <1-50>:"))
    if palpite == n_secreto:
       print("Parabéns! você acertou!")
       break
    else:
         if (palpite > (n_secreto - 5)) and (palpite < (n_secreto + 5)):
        
            print("Está Quente")
         else:              
           print("Está frio")
    
    print("acabou")
# Out:
# Digite um numero <1-50>: 10
# Está frio
# acabou
# Digite um numero <1-50>: 15
# Está frio
# acabou
# Digite um numero <1-50>: 20
# Está frio
# acabou
# Digite um numero <1-50>: 10
# Está frio
# acabou
# Digite um numero <1-50>: 30
# Está frio
# acabou

# %%
import random
tentativa = 0
n_secreto = random.randint(1 ,50)

while tentativa < 5 :
    palpite = int(input("Digite um numero <1-50>:"))
    tentativa = tentativa + 1
    
    if palpite == n_secreto:
     print("Parabéns! você acertou!")
     break
else:
    print("Errou")
    if palpite > n_secreto:
        print("Errou!!!tente um numero menor!")
    else:         
        print("Errou!!! tente um numero maior! ")
    print(f"Tentativa {tentativa} de 5")

print(" Acabou !!!")
# Out:
# Digite um numero <1-50>: 15
# Digite um numero <1-50>: 20
# Parabéns! você acertou!
#  Acabou !!!
