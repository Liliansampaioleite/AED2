# %%
import random
numero_secreto = random.randint(1, 50)
print(f"O numero escolhido foi: {numero_secreto}")
# Out:
# O numero escolhido foi: 22

# %%
# import random
numero_secreto = random.randint(1, 10)
tentativa = 0
print("Tente adivinhar o numero que eu escolhi ente 1 e 10 !")
while tentativa != numero_secreto:
    tentativa = (int(input("Qual é o seu Palpite")))
    if tentativa < numero_secreto :
        print("Mais alto...")
    elif tentativa > numero_secreto:
          print("Mais baixo...")
    else:
        print(f"Acertou! O número era {numero_secreto}!")
# Out:
# Tente adivinhar o numero que eu escolhi ente 1 e 10 !
# Qual é o seu Palpite 5
# Mais alto...
# Qual é o seu Palpite 6
# Mais alto...
# Qual é o seu Palpite 8
# Mais alto...
# Qual é o seu Palpite 9
# Acertou! O número era 9!
